# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.666237  2.358554 -0.647461  1.094508  0.380254       0
# 1  0.234830 -1.754392 -0.096877 -0.617783 -0.990639       1
# 2 -1.841754 -0.839747 -1.427344 -1.941951 -1.998567       1
# 3 -0.277083 -0.838522 -0.484777 -0.839735  0.133547       1
# 4  0.290442 -0.943120 -0.625382  1.733599  3.379748       1

# %%
def sample_rows(df,percent):
    return df.sample(int(percent*df.shape[0]))

# %%
def sample_cols(df,percent):
    new_df = df.iloc[:,:-1].sample(int(percent*df.iloc[:,:-1].shape[1]),axis=1)
    new_df['target'] = df['target']
    return new_df

# %%
def sample_rows_cols(df,row_percent,col_percent):
    return sample_rows(sample_cols(df,col_percent),row_percent)

# %%
df1 = sample_rows_cols(df,0.5,0.5)

# %%
df2 = sample_rows_cols(df,0.5,0.5)

# %%
df3 = sample_rows_cols(df,0.5,0.5)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,:-1],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,:-1],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,:-1],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.29017857142857145, 0.95, 'x[0] <= -1.887\ngini = 0.493\nsamples = 50\nvalue = [22.0, 28.0]'),
#  Text(0.10714285714285714, 0.85, 'x[0] <= -3.024\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.07142857142857142, 0.75, 'x[1] <= -1.583\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03571428571428571, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10714285714285714, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14285714285714285, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4732142857142857, 0.85, 'x[1] <= -0.4\ngini = 0.474\nsamples = 44\nvalue = [17, 27]'),
#  Text(0.26785714285714285, 0.75, 'x[1] <= -1.823\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.17857142857142858, 0.65, 'x[1] <= -2.564\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14285714285714285, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21428571428571427, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.5952380952380952, 0.95, 'x[1] <= -0.192\ngini = 0.497\nsamples = 50\nvalue = [23, 27]'),
#  Text(0.3333333333333333, 0.85, 'x[1] <= -1.416\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(0.23809523809523808, 0.75, 'x[1] <= -1.697\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.19047619047619047, 0.65, 'x[1] <= -1.943\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.14285714285714285, 0.55, 'x[0] <= -2.751\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.09523809523809523, 0.45, 'x[0] <= -3.158\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.047619047619047616, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14285714285714285, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19047619047619047, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.23809523809523808, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2857142857142857, 0.65, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.1693121693121693, 0.9583333333333334, 'x[1] <= -1.887\ngini = 0.499\nsamples = 50\nvalue = [24, 26]'),
#  Text(0.08465608465608465, 0.875, 'x[0] <= -3.9\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.042328042328042326, 0.7916666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12698412698412698, 0.7916666666666666, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.25396825396825395, 0.875, 'x[0] <= -2.315\ngini = 0.487\nsamples = 43\nvalue = [18, 25]'),
#  Text(0.21164021164021163, 0.7916666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2962962962962963, 0.7916666666666666, 'x[0] <= -1.445\ngini = 0.469\nsamples = 40\nvalue = [15, 25]'),
#  Text(0.25396825396825395, 0.7083333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3386243386243386, 0.7083333333333334, 'x[0] <= -1.04\ngini = 0.49\nsamples = 35\nvalue = [15, 20]'),
#  Text(0.2962962962962963, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
df
# Out:
#         col1      col2      col3      col4      col5  target
# 0  -0.666237  2.358554 -0.647461  1.094508  0.380254       0
# 1   0.234830 -1.754392 -0.096877 -0.617783 -0.990639       1
# 2  -1.841754 -0.839747 -1.427344 -1.941951 -1.998567       1
# 3  -0.277083 -0.838522 -0.484777 -0.839735  0.133547       1
# 4   0.290442 -0.943120 -0.625382  1.733599  3.379748       1
# ..       ...       ...       ...       ...       ...     ...
# 95  1.941662 -0.986209 -1.196523 -0.961566  0.055722       1
# 96 -1.392752  0.000630 -0.959068  3.541285 -0.076109       0
# 97 -0.381035 -1.080401 -3.127690 -2.516341 -4.300212       1
# 98  4.775074 -1.298704 -3.733905 -1.649615 -3.407772       0
# 99 -1.144122  2.202517  0.459183 -0.021863  0.773120       0
#
# [100 rows x 6 columns]

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col3', 'col2', 'target'], dtype='object')
# Index(['col3', 'col4', 'target'], dtype='object')
# Index(['col5', 'col3', 'target'], dtype='object')

# %%
# 0.234830	-1.754392	-0.096877	-0.617783	-0.990639	1
print(clf1.predict([[-0.096877,-1.754392]]))
print(clf2.predict([[-0.096877,-0.617783]]))
print(clf3.predict([[-0.990639,-0.096877]]))
# crct
# Out:
# [1]
# [0]
# [1]
# /home/janardhan/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /home/janardhan/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /home/janardhan/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
