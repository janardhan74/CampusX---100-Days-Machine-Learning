# %%
import pandas as pd
import requests

# %%
api_key = "3cbdee7cc20f42459638cfe0fde36b3e"
url = "https://newsapi.org/v2/everything?q=general&apiKey={}".format(api_key)

response = requests.get(url)

df = pd.DataFrame(response.json()['articles'])

# %%
df
# Out:
#                                          source           author  \
# 0   {'id': None, 'name': 'Yahoo Entertainment'}  Danny Gallagher
# 1             {'id': None, 'name': '[Removed]'}             None
# 2              {'id': None, 'name': 'BBC News'}             None
# 3              {'id': None, 'name': 'BBC News'}             None
# 4        {'id': 'bbc-news', 'name': 'BBC News'}             None
# ..                                          ...              ...
# 95  {'id': None, 'name': 'Yahoo Entertainment'}    Mariella Moon
# 96  {'id': None, 'name': 'Yahoo Entertainment'}    Mariella Moon
# 97            {'id': None, 'name': 'ReadWrite'}  Radek Zielinski
# 98             {'id': None, 'name': 'BBC News'}             None
# 99       {'id': 'abc-news', 'name': 'ABC News'}        Luke Barr
#
#                                                 title  \
# 0   General Motors revives its robotaxi service Cr...
# 1                                           [Removed]
# ...
