# %%
import pandas as pd

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,:-1].values,df.iloc[:,-1].values,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((768, 13), (257, 13))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy_score(y_test,rfc.predict(x_test))
# Out:
# 0.9883268482490273

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(RandomForestClassifier(),df.iloc[:,:-1].values,df.iloc[:,-1].values,cv=5,scoring='accuracy').mean()
# Out:
# 0.9941463414634146

# %% [markdown]
# ### GridSearchCV

# %%
n_estimators = [20,60,100,120]
max_features = [0.2,0.6,1.0]
max_samples = [0.2,0.6,1.0]
max_depth = [2,8,None]

# %%
param_grid = {
    'n_estimators':n_estimators,
    'max_features':max_features,
    'max_samples':max_samples,
    'max_depth':max_depth
}

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
gs = GridSearchCV(estimator=RandomForestClassifier(),
                 param_grid=param_grid,
                 cv=10,
                 verbose=1)

# %%
gs.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 8, None],
#                          'max_features': [0.2, 0.6, 1.0],
#                          'max_samples': [0.2, 0.6, 1.0],
#                          'n_estimators': [20, 60, 100, 120]},
#              verbose=1)

# %%
gs.best_score_
# Out:
# 0.9869446343130551

# %%
gs.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 1.0,
#  'max_samples': 1.0,
#  'n_estimators': 100}

# %% [markdown]
# ### RandomSearchCV

# %%
rs = RandomizedSearchCV(estimator=RandomForestClassifier() ,
                        param_distributions=param_grid,
                       cv=5,
                       verbose=2)
rs.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=None, max_features=0.6, max_samples=0.2, n_estimators=60; total time=   0.3s
# [CV] END max_depth=None, max_features=0.6, max_samples=0.2, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=0.6, max_samples=0.2, n_estimators=60; total time=   0.1s
# [CV] END max_depth=None, max_features=0.6, max_samples=0.2, n_estimators=60; total time=   0.1s
# [CV] END max_depth=None, max_features=0.6, max_samples=0.2, n_estimators=60; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=20; total time=   0.1s
# [CV] END max_depth=None, max_features=1.0, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=1.0, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=1.0, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=1.0, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=1.0, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=0.6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=120; total time=   0.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=120; total time=   0.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=120; total time=   0.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=120; total time=   0.4s
# [CV] END max_depth=8, max_features=1.0, max_samples=1.0, n_estimators=120; total time=   0.4s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=1.0, max_samples=0.6, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=1.0, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=1.0, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=1.0, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=1.0, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=1.0, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=0.6, max_samples=0.2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=2, max_features=0.2, max_samples=0.6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.2, max_samples=0.6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.2, max_samples=0.6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.2, max_samples=0.6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=2, max_features=0.2, max_samples=0.6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=8, max_features=0.2, max_samples=1.0, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=0.2, max_samples=1.0, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=0.2, max_samples=1.0, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=0.2, max_samples=1.0, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=0.2, max_samples=1.0, n_estimators=100; total time=   0.2s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [2, 8, None],
#                                         'max_features': [0.2, 0.6, 1.0],
#                                         'max_samples': [0.2, 0.6, 1.0],
#                                         'n_estimators': [20, 60, 100, 120]},
#                    verbose=2)

# %%
rs.best_score_
# Out:
# 0.9687123334182159

# %%
rs.best_params_
# Out:
# {'n_estimators': 120, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 8}

# %% [markdown]
# ### Video 96 - OOB Score

# %%
df = pd.read_csv('heart.csv')
rfc = RandomForestClassifier(oob_score=True)
rfc.fit(df.iloc[:,:-1].values,df.iloc[:,-1].values)
# Out:
# RandomForestClassifier(oob_score=True)

# %%
rfc.oob_score_
# Out:
# 1.0

# %%
test = df.sample(100)
accuracy_score(test.iloc[:,-1],rfc.predict(test.iloc[:,:-1]))
# Out:
# /home/janardhan/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# 1.0
